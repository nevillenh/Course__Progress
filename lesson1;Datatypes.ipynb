# %%
#integers
type(12)
# Out:
# int

# %%
#float
type(12.0)
# Out:
# float

# %%
#strings
type("Hello World")
# Out:
# str

# %%
#list
type([1, 2, 3])
# Out:
# list

# %%
[1, 2, 3 ]
# Out:
# [1, 2, 3]

# %%
ice_cream = ["chocolate", "vanilla", "strawberry"]
ice_cream.append("mint")
ice_cream
# Out:
# ['chocolate', 'vanilla', 'strawberry', 'mint']

# %%
ice_cream[0]="caramel"
ice_cream
# Out:
# ['caramel', 'vanilla', 'strawberry', 'mint']

# %%
#tuple
marks=(2,3,4,2,6)
type(marks)
# Out:
# tuple

# %%
marks.append(8)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 marks.append(8)
#
# AttributeError: 'tuple' object has no attribute 'append'
