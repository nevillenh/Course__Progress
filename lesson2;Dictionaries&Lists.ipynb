# %%
#dictionaries
student_data = {"name": "John", "age": 20, "grade": "A"}
type(student_data)
# Out:
# dict

# %%
print(student_data)
# Out:
# {'name': 'John', 'age': 20, 'grade': 'A'}

# %%
student_data.keys()
# Out:
# dict_keys(['name', 'age', 'grade'])

# %%
student_data.values()
# Out:
# dict_values(['John', 20, 'A'])

# %%
student_data.items()
# Out:
# dict_items([('name', 'John'), ('age', 20), ('grade', 'A')])

# %%
student_data["name"]
# Out:
# 'John'

# %%
student_data["name"] = "Alice"
print(student_data)
# Out:
# {'name': 'Alice', 'age': 20, 'grade': 'A'}

# %%
student_data.update({"weight": 70})
print(student_data)
# Out:
# {'name': 'Alice', 'age': 20, 'grade': 'A', 'weight': 70}

# %%
del student_data["age"]
print(student_data)
# Out:
# {'name': 'Alice', 'grade': 'A', 'weight': 70}

# %%
# strings
name= "neville"
surname= "heyi"
age="19"
print("My name is " + name + " " + surname + " and I am " + (age) + " years old.")
# Out:
# My name is neville heyi and I am 19 years old.

# %%
print(len(name))
# Out:
# 7

# %%
print(name.capitalize())
# Out:
# Neville

# %%
print(surname.find("y"))
# Out:
# 2

# %%
print(surname.index("y"))
# Out:
# 2

# %%
print(name.replace('n', 'd'))
# Out:
# deville

# %%
print(name.split('e'))
# Out:
# ['n', 'vill', '']

# %%
print(surname.upper())
# Out:
# HEYI
